# %%
pip install ultralytics

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls
# Out:
# data.yaml  runs  test  train  val  yolov8n.pt

# %%
# %cd /content/drive/MyDrive/model/Dataset/
# Out:
# /content/drive/MyDrive/model/Dataset

# %%
# !yolo detect train data=data.yaml model=yolov8n.pt epochs=100 imgsz=256
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls runs/detect/train
# Out:
# args.yaml					    P_curve.png		train_batch181.jpg
# confusion_matrix_normalized.png			    PR_curve.png	train_batch182.jpg
# confusion_matrix.png				    R_curve.png		train_batch1.jpg
# events.out.tfevents.1727623212.4014af2e60f7.3789.0  results.csv		train_batch2.jpg
# F1_curve.png					    results.png		val_batch0_labels.jpg
# labels_correlogram.jpg				    train_batch0.jpg	val_batch0_pred.jpg
# labels.jpg					    train_batch180.jpg	weights

# %%
# !yolo detect val model=runs/detect/train/weights/best.pt data=data.yaml
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/model/Dataset/val/labels.cache... 27 images, 0 backgrounds, 0 corrupt: 100% 27/27 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 2/2 [00:02<00:00,  1.09s/it]
#                    all         27         33      0.654      0.902      0.922      0.823
#                garbage         27         28      0.864          1      0.988       0.87
#                 person          5          5      0.445      0.803      0.855      0.776
# Speed: 1.5ms preprocess, 12.9ms inference, 0.0ms loss, 46.9ms postprocess per image
# Results saved to runs/detect/val2
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo detect predict model=yolov8n.pt conf=0.25 source=/content/drive/MyDrive/model/Dataset/test
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# image 1/10 /content/drive/MyDrive/model/Dataset/test/black poly (26).jpg: 640x352 1 person, 104.0ms
# image 2/10 /content/drive/MyDrive/model/Dataset/test/black-1.jpg: 384x640 1 person, 1 handbag, 38.9ms
# image 3/10 /content/drive/MyDrive/model/Dataset/test/black-2.jpg: 384x640 1 person, 1 handbag, 6.9ms
# image 4/10 /content/drive/MyDrive/model/Dataset/test/black-6.jpg: 384x640 1 person, 1 handbag, 8.3ms
# image 5/10 /content/drive/MyDrive/model/Dataset/test/frame_0.jpg: 640x384 1 person, 38.5ms
# image 6/10 /content/drive/MyDrive/model/Dataset/test/frame_1.jpg: 640x384 1 person, 6.8ms
# image 7/10 /content/drive/MyDrive/model/Dataset/test/frame_5.jpg: 640x384 1 person, 6.8ms
# image 8/10 /content/drive/MyDrive/model/Dataset/test/white-1.jpg: 640x384 3 persons, 6.8ms
# ...

# %%
# !yolo detect predict model=runs/detect/train/weights/best.pt conf=0.25 source='https://th.bing.com/th/id/OIP.EwHlshVKdP7SZ8QxUGbWVwHaE8?w=1200&h=800&rs=1&pid=ImgDetMain'
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
#
# 1/1: https://th.bing.com/th/id/OIP.EwHlshVKdP7SZ8QxUGbWVwHaE8?w=1200&h=800&rs=1&pid=ImgDetMain... Success ✅ (inf frames of shape 1200x800 at 25.00 FPS)
#
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# WARNING ⚠️ Video stream unresponsive, please check your IP camera connection.
# ...
